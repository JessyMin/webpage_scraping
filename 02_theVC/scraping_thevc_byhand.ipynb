# %% [markdown]
# - theVC는 크롤링을 의도적으로 막아놓았다.
#     - '스타트업 검색'에서 한번에 30개씩 로딩할 수 있다.
#     - 대분류/투자단계에 필터를 걸어도 url은 바뀌지 않으므로 request는 사용할 수 없다.
#     - selenium을 사용하려 하면, 제어되는 브라우저에서 로그인이 되지 않는다. (리캡차 무한반복)
# - 따라서 마우스드래그로 긁어 메모장에서 data.txt로 저장해 사용합니다.

# %%
import pandas as pd

# %% [markdown]
# ### text 파일 읽어오기

# %%
path = "data.txt"

with open(path, "r", encoding='UTF8') as file:
    strings = file.readlines()
    print(strings)
# Out:
# ['차오르다\n', '한국∙스타트업\n', '클라우드스쿨\n', '1:1 온라인 강의 서비스\n', '음악/영상스트리밍\t교육\t과외/레슨\t웹사이트\t대전광역시\t0.8년\t비공개\t비공개\t비공개\tseed\t2021-01-27\t더보기 \n', '트이다\n', '한국∙스타트업\n', '트이다\n', '베트남 기반 한국어 회화 학습 서비스\n', '이미지/영상제작\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t2.0년\t3명\t비공개\t비공개\tpre-A\t2021-01-22\t더보기 \n', '플링크\n', '한국∙스타트업\n', '페이지콜\n', '온디맨드 온라인 커뮤니케이션 소프트웨어\n', '이미지/영상처리\t교육\t교육보조\t웹사이트\t서울특별시\t5.2년\t19명\t7억\t42억\tseries A\t2021-01-05\t더보기 \n', '지란지교컴즈\n', '한국∙중소기업\n', '쿨메신저\n', '전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저\n', '리얼타임 커뮤니케이션\t교육\t메신저\tNone\t서울특별시\t5.1년\t18명\t10억\t10억\tseries A\t2021-01-04\t더보기 \n', '펍플\n', '한국∙스타트업\n', '펍플\n', '클라우드기반 교육 출판 솔루션\n', '클라우드\t교육\t도서\t소프트웨어\t고양시\t5.2년\t23명\t4억\t5억\tseed\t2020-12-31\t더보기 \n', '스터디파이\n', '한국∙스타트업\n', '스터디파이\n', '온라인 스터디 중개 플랫폼\n', '리얼타임 커뮤니케이션\t교육\t과외/레슨\t웹사이트\t서울특별시\t2.4년\t15명\t15억\t34억\tseries A\t2020-12-30\t더보기 \n', '하얀마인드\n', '한국∙스타트업\n', '레드키위\n', '영상기반 영어 말하기 연습용 모바일 앱\n', '음악/영상스트리밍\t교육\t외국어교육\t모바일앱-iOS\t대전광역시\t3.6년\t15명\t2.2억\t7.5억\tpre-A\t2020-12-29\t더보기 \n', '이십사점오\n', '한국∙스타트업\n', '슥삭\n', '대외활동, 공모전, 서포터즈, 인턴, 동아리 추천 앱\n', '검색\t교육\t정보제공\t모바일앱-iOS\t서울특별시\t1.5년\t5명\t1.5억\t1.5억\tseed\t2020-12-24\t더보기 \n', '키즈페이\n', '한국∙스타트업\n', '키즈페이\n', '영업지사와 영유아 교육기관의 비대면 결제 관리 프로그램\n', '클라우드\t교육\t회계/세무\t웹사이트\t서울특별시\t1.2년\t3명\t비공개\t비공개\tseed\t2020-12-23\t더보기 \n', '단꿈아이\n', '한국∙스타트업\n', '설쌤TV\n', '한국사&인문학 기반 재미와 유익을 제공하는 컨텐츠 IP 서비스\n', '이미지/영상제작\t교육\t대안교육\t콘
�사이트\t성남시\t3.2년\t3명\t2억\t2억\tseed\t2020-10-21\t더보기 ', '산타', '한국∙스타트업', '디디캐스트', '온라인 강의제작 솔루션', '클라우드\t교육\t이미지/영상\t웹사이트\t부산광역시\t4.3년\t24명\t7억\t38억\tseries A\t2020-10-19\t더보기 ', '태인교육', '한국∙스타트업', '파인듀', '학원 정보 플랫폼', '검색\t교육\t학원\t웹사이트\t서울특별시\t5.9년\t8명\t비공개\t비공개\tseed\t2020-10-16\t더보기 ', '퀄슨', '한국∙스타트업', '슈퍼팬', '미드, 영화로 배우는 영어 회화 앱', '음악/영상스트리밍\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t8.6년\t91명\t75억\t152억\tseries B\t2020-10-14\t더보기 ', '호두랩스', '한국∙스타트업', '호두잉글리쉬', '스토리 기반의 영어 학습 게임', '게임개발\t교육\t외국어교육\t소프트웨어\t서울특별시\t2.2년\t52명\t50억\t155억\tseries A\t2020-10-06\t더보기 ', '레드윗', '한국∙스타트업', '구노', '블록체인 기반 연구노트 서비스', '블록체인\t교육\t연구/실험\t모바일앱-iOS\t대전광역시\t1.5년\t9명\t5억\t13억\t지원금\t2020-09-25\t더보기']

# %%
# 잘못 들어간 값 제거
test.remove('더보기')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6ee5bcdca00d> in <module>
#       1 # 잘못 들어간 값 제거
# ----> 2 test.remove('더보기')
#
# ValueError: list.remove(x): x not in list

# %%
# 회사,서비스,설명,상세정보 추출

company = []
service = []
description = []
detail = []

for i in range(0, len(test)):
    if i % 5 == 0:
        company.append(test[i])
    elif i % 5 == 2:
        service.append(test[i])
    elif i % 5 == 3:
        description.append(test[i])
    elif i % 5 == 4:
        detail.append(test[i])
    else:
        pass

print(company)
# Out:
# ['차오르다', '트이다', '플링크', '지란지교컴즈', '펍플', '스터디파이', '하얀마인드', '이십사점오', '키즈페이', '단꿈아이', '유니브', '러너스마인드', '청그라미', '플랭', '이리온컴퍼니', '산타', '태인교육', '퀄슨', '호두랩스', '레드윗']

# %% [markdown]
# - 만약 깔끔하게 나오지 않는다면, 별도 행으로 '더보기'가 들어간 것이다.
# - txt 파일에서 지워줘야 함

# %%
# 리스트별 개수가 맞는지 확인

print(len(company))
print(len(service))
print(len(description))
print(len(detail))
# Out:
# 20
# 20
# 20
# 20

# %% [markdown]
# ### 데이터프레임으로 합치기

# %%
# 데이터프레임으로 저장하기

df = []

zippedList = list(zip(company, service, description, detail))

df= pd.DataFrame(zippedList, columns = ['company', 'service', 'description', 'detail'])

df.head()
# Out:
#   company service                                    description  \
# 0    차오르다  클라우드스쿨                                 1:1 온라인 강의 서비스
# 1     트이다     트이다                           베트남 기반 한국어 회화 학습 서비스
# 2     플링크    페이지콜                          온디맨드 온라인 커뮤니케이션 소프트웨어
# 3  지란지교컴즈    쿨메신저  전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저
# 4      펍플      펍플                               클라우드기반 교육 출판 솔루션
#
#                                               detail
# 0  음악/영상스트리밍\t교육\t과외/레슨\t웹사이트\t대전광역시\t0.8년\t비공개\t...
# 1  이미지/영상제작\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t2.0년\t3명...
# 2  이미지/영상처리\t교육\t교육보조\t웹사이트\t서울특별시\t5.2년\t19명\t7억...
# 3  리얼타임 커뮤니케이션\t교육\t메신저\tNone\t서울특별시\t5.1년\t18명\t...
# 4  클라우드\t교육\t도서\t소프트웨어\t고양시\t5.2년\t23명\t4억\t5억\ts...

# %%
df.shape

# %%
# 중복된 업체 제거하기

df = df.drop_duplicates()
df.shape[0]
# Out:
# 20

# %% [markdown]
# ### detail 정보 분리하기

# %%
# 대분류
def split_desc(detail):
    return detail.split("\t")[1]

df['category1'] = df['detail'].apply(split_desc)

# 소분류
def split_desc(detail):
    return detail.split("\t")[2]

df['category2'] = df['detail'].apply(split_desc)

# 총 투자금액
def split_desc(detail):
    return detail.split("\t")[8]

df['ir_total_amount'] = df['detail'].apply(split_desc)

# 현재 투자단계
def split_desc(detail):
    return detail.split("\t")[9]

df['ir_stage'] = df['detail'].apply(split_desc)

# 최근 투자날짜
def split_desc(detail):
    return detail.split("\t")[10]

df['ir_date'] = df['detail'].apply(split_desc)

# %%
# 연도만 추출
df['funding_year_month'] = df['ir_date'].str[0:7]
df['funding_year'] = df['ir_date'].str[0:4]
df.head()
# Out:
#   company service                                    description  \
# 0    차오르다  클라우드스쿨                                 1:1 온라인 강의 서비스
# 1     트이다     트이다                           베트남 기반 한국어 회화 학습 서비스
# 2     플링크    페이지콜                          온디맨드 온라인 커뮤니케이션 소프트웨어
# 3  지란지교컴즈    쿨메신저  전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저
# 4      펍플      펍플                               클라우드기반 교육 출판 솔루션
#
#                                               detail category1 category2  \
# 0  음악/영상스트리밍\t교육\t과외/레슨\t웹사이트\t대전광역시\t0.8년\t비공개\t...        교육     과외/레슨
# 1  이미지/영상제작\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t2.0년\t3명...        교육     외국어교육
# 2  이미지/영상처리\t교육\t교육보조\t웹사이트\t서울특별시\t5.2년\t19명\t7억...        교육      교육보조
# 3  리얼타임 커뮤니케이션\t교육\t메신저\tNone\t서울특별시\t5.1년\t18명\t...        교육       메신저
# 4  클라우드\t교육\t도서\t소프트웨어\t고양시\t5.2년\t23명\t4억\t5억\ts...        교육        도서
#
#   ir_total_amount  ir_stage     ir_date funding_year_month funding_year
# 0             비공개      seed  2021-01-27            2021-01         2021
# 1             비공개     pre-A  2021-01-22            2021-01         2021
# 2             42억  series A  2021-01-05            2021-01         2021
# 3             10억  series A  2021-01-04            2021-01         2021
# 4              5억      seed  2020-12-31            2020-12         2020

# %%
# 나머지 정보 붙이기 : 기술, 서비스 타입

# 기술
def split_desc(detail):
    return detail.split("\t")[0]

df['tech'] = df['detail'].apply(split_desc)

# 서비스 형태
def split_desc(detail):
    return detail.split("\t")[3]

df['service_type'] = df['detail'].apply(split_desc)

# %%
# detail, 투자날짜 컬럼 지우기
df.drop('detail', axis=1, inplace=True)
df.drop('ir_date', axis=1, inplace=True)
df.head()
# Out:
#   company service                                    description category1  \
# 0    차오르다  클라우드스쿨                                 1:1 온라인 강의 서비스        교육
# 1     트이다     트이다                           베트남 기반 한국어 회화 학습 서비스        교육
# 2     플링크    페이지콜                          온디맨드 온라인 커뮤니케이션 소프트웨어        교육
# 3  지란지교컴즈    쿨메신저  전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저        교육
# 4      펍플      펍플                               클라우드기반 교육 출판 솔루션        교육
#
#   category2 ir_total_amount  ir_stage funding_year_month funding_year  \
# 0     과외/레슨             비공개      seed            2021-01         2021
# 1     외국어교육             비공개     pre-A            2021-01         2021
# 2      교육보조             42억  series A            2021-01         2021
# 3       메신저             10억  series A            2021-01         2021
# 4        도서              5억      seed            2020-12         2020
#
#           tech service_type
# 0    음악/영상스트리밍         웹사이트
# 1     이미지/영상제작     모바일앱-iOS
# 2     이미지/영상처리         웹사이트
# 3  리얼타임 커뮤니케이션         None
# 4         클라우드        소프트웨어

# %% [markdown]
# ### 투자금액 전처리

# %%
# '억' 텍스트 제거 

df['ir_total_amount'] = df['ir_total_amount'].str.replace("억", "")
df.head(40)
# Out:
#    company       service                                    description  \
# 0     차오르다        클라우드스쿨                                 1:1 온라인 강의 서비스
# 1      트이다           트이다                           베트남 기반 한국어 회화 학습 서비스
# 2      플링크          페이지콜                          온디맨드 온라인 커뮤니케이션 소프트웨어
# 3   지란지교컴즈          쿨메신저  전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저
# 4       펍플            펍플                               클라우드기반 교육 출판 솔루션
# 5    스터디파이         스터디파이                                 온라인 스터디 중개 플랫폼
# 6    하얀마인드          레드키위                          영상기반 영어 말하기 연습용 모바일 앱
# 7    이십사점오            슥삭                  대외활동, 공모전, 서포터즈, 인턴, 동아리 추천 앱
# 8     키즈페이          키즈페이                 영업지사와 영유아 교육기관의 비대면 결제 관리 프로그램
# 9     단꿈아이          설쌤TV             한국사&인문학 기반 재미와 유익을 제공하는 컨텐츠 IP 서비스
# 10     유니브          연고티비                             교육/대학 전문 MCN 매니지먼트
# 11  러너스마인드         클래스카드                           영어쌤 1/3이 선택한 스마트 단어장
# 12    청그라미  아산 YMCA 청년센터                   충남 지역 사회혁신 창업교육 프로그램 및 공간 운영
# 13      플랭            플랭                            AI 스피킹, 영어회화 트레이닝 앱
# 14  이리온컴퍼니           이리온                  실시간으로 상호작용이 가능한 쌍방향 화상 교육 플랫폼
# 15      산타         디디캐스트                                   온라인 강의제작 솔루션
# 16    태인교육           파인듀                                      학원 정보 플랫폼
# 17      퀄슨           슈퍼팬                            미드, 영화로 배우는 영어 회화 앱
# 18    호두랩스        호두잉글리쉬                               스토리 기반의 영어 학습 게임
# 19     레드윗            구노                               블록체인 기반 연구노트 서비스
#
#    category1 category2 ir_total_amount  ir_stage funding_year_month  \
# 0         교육     과외/레슨             비공개      seed            2021-01
# 1         교육     외국어교육             비공개     pre-A            2021-01
# 2         교육      교육보조              42  series A            2021-01
# 3         교육       메신저              10  series A            2021-01
# 4         교육        도서               5      seed            2020-12
# 5         교육     과외/레슨              34  series A            2020-12
# 6         교육     외국어교육             7.5     pre-A            2020-12
# 7         교육      정보제공             1.5      seed            2020-12
# 8         교육     회계/세무             비공개      seed            2020-12
# 9         교육      대안교육              70  series A            2020-12
# 10        교육       MCN              25  series A            2020-11
# 11        교육     외국어교육            4천만원      seed            2020-11
# 12        교육      기업지원             비공개      seed            2020-10
# 13        교육     외국어교육               5     pre-A            2020-10
# 14        교육      교육보조               2      seed            2020-10
# 15        교육    이미지/영상              38  series A            2020-10
# 16        교육        학원             비공개      seed            2020-10
# 17        교육     외국어교육             152  series B            2020-10
# 18        교육     외국어교육             155  series A            2020-10
# 19        교육     연구/실험              13       지원금            2020-09
#
#    funding_year         tech service_type
# 0          2021    음악/영상스트리밍         웹사이트
# 1          2021     이미지/영상제작     모바일앱-iOS
# 2          2021     이미지/영상처리         웹사이트
# 3          2021  리얼타임 커뮤니케이션         None
# 4          2020         클라우드        소프트웨어
# 5          2020  리얼타임 커뮤니케이션         웹사이트
# 6          2020    음악/영상스트리밍     모바일앱-iOS
# 7          2020           검색     모바일앱-iOS
# 8          2020         클라우드         웹사이트
# 9          2020     이미지/영상제작          콘텐츠
# 10         2020     이미지/영상제작       교육/컨설팅
# 11         2020      빅데이터/분석     모바일앱-iOS
# 12         2020          N/A         프로그램
# 13         2020         인공지능         None
# 14         2020    음악/영상스트리밍         웹사이트
# 15         2020         클라우드         웹사이트
# 16         2020           검색         웹사이트
# 17         2020    음악/영상스트리밍     모바일앱-iOS
# 18         2020         게임개발        소프트웨어
# 19         2020         블록체인     모바일앱-iOS

# %%
# O천만원 -> 억으로 변환

def transform(amount):
    if "천만원" in amount:
        amount = amount.replace("천만원", "")
        amount = int(amount) * 0.1
    return amount
    
    
df['ir_total_amount'] = df['ir_total_amount'].apply(transform)
df.head(40)
# df['ir_total_amount'].str.contains("천만원").sum()
# Out:
#    company       service                                    description  \
# 0     차오르다        클라우드스쿨                                 1:1 온라인 강의 서비스
# 1      트이다           트이다                           베트남 기반 한국어 회화 학습 서비스
# 2      플링크          페이지콜                          온디맨드 온라인 커뮤니케이션 소프트웨어
# 3   지란지교컴즈          쿨메신저  전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저
# 4       펍플            펍플                               클라우드기반 교육 출판 솔루션
# 5    스터디파이         스터디파이                                 온라인 스터디 중개 플랫폼
# 6    하얀마인드          레드키위                          영상기반 영어 말하기 연습용 모바일 앱
# 7    이십사점오            슥삭                  대외활동, 공모전, 서포터즈, 인턴, 동아리 추천 앱
# 8     키즈페이          키즈페이                 영업지사와 영유아 교육기관의 비대면 결제 관리 프로그램
# 9     단꿈아이          설쌤TV             한국사&인문학 기반 재미와 유익을 제공하는 컨텐츠 IP 서비스
# 10     유니브          연고티비                             교육/대학 전문 MCN 매니지먼트
# 11  러너스마인드         클래스카드                           영어쌤 1/3이 선택한 스마트 단어장
# 12    청그라미  아산 YMCA 청년센터                   충남 지역 사회혁신 창업교육 프로그램 및 공간 운영
# 13      플랭            플랭                            AI 스피킹, 영어회화 트레이닝 앱
# 14  이리온컴퍼니           이리온                  실시간으로 상호작용이 가능한 쌍방향 화상 교육 플랫폼
# 15      산타         디디캐스트                                   온라인 강의제작 솔루션
# 16    태인교육           파인듀                                      학원 정보 플랫폼
# 17      퀄슨           슈퍼팬                            미드, 영화로 배우는 영어 회화 앱
# 18    호두랩스        호두잉글리쉬                               스토리 기반의 영어 학습 게임
# 19     레드윗            구노                               블록체인 기반 연구노트 서비스
#
#    category1 category2 ir_total_amount  ir_stage funding_year_month  \
# 0         교육     과외/레슨             비공개      seed            2021-01
# 1         교육     외국어교육             비공개     pre-A            2021-01
# 2         교육      교육보조              42  series A            2021-01
# 3         교육       메신저              10  series A            2021-01
# 4         교육        도서               5      seed            2020-12
# 5         교육     과외/레슨              34  series A            2020-12
# 6         교육     외국어교육             7.5     pre-A            2020-12
# 7         교육      정보제공             1.5      seed            2020-12
# 8         교육     회계/세무             비공개      seed            2020-12
# 9         교육      대안교육              70  series A            2020-12
# 10        교육       MCN              25  series A            2020-11
# 11        교육     외국어교육             0.4      seed            2020-11
# 12        교육      기업지원             비공개      seed            2020-10
# 13        교육     외국어교육               5     pre-A            2020-10
# 14        교육      교육보조               2      seed            2020-10
# 15        교육    이미지/영상              38  series A            2020-10
# 16        교육        학원             비공개      seed            2020-10
# 17        교육     외국어교육             152  series B            2020-10
# 18        교육     외국어교육             155  series A            2020-10
# 19        교육     연구/실험              13       지원금            2020-09
#
#    funding_year         tech service_type
# 0          2021    음악/영상스트리밍         웹사이트
# 1          2021     이미지/영상제작     모바일앱-iOS
# 2          2021     이미지/영상처리         웹사이트
# 3          2021  리얼타임 커뮤니케이션         None
# 4          2020         클라우드        소프트웨어
# 5          2020  리얼타임 커뮤니케이션         웹사이트
# 6          2020    음악/영상스트리밍     모바일앱-iOS
# 7          2020           검색     모바일앱-iOS
# 8          2020         클라우드         웹사이트
# 9          2020     이미지/영상제작          콘텐츠
# 10         2020     이미지/영상제작       교육/컨설팅
# 11         2020      빅데이터/분석     모바일앱-iOS
# 12         2020          N/A         프로그램
# 13         2020         인공지능         None
# 14         2020    음악/영상스트리밍         웹사이트
# 15         2020         클라우드         웹사이트
# 16         2020           검색         웹사이트
# 17         2020    음악/영상스트리밍     모바일앱-iOS
# 18         2020         게임개발        소프트웨어
# 19         2020         블록체인     모바일앱-iOS

# %%
# '비공개' 텍스트 제거, 숫자형으로 변환

#df['ir_total_amount'] = df['ir_total_amount'].str.replace("비공개", "0")

#df['ir_total_amount'] = pd.to_numeric(df['ir_total_amount'])
#df.info()

# %% [markdown]
# ### 서비스 타입 전처리

# %%
# 서비스 타입 전처리

df['service_type'] = df['service_type'].str.replace("-iOS","")
df['service_type'] = df['service_type'].str.replace("-Android","")

df['service_type'].value_counts()
# Out:
# 웹사이트      7
# 모바일앱      6
# None      2
# 소프트웨어     2
# 교육/컨설팅    1
# 콘텐츠       1
# 프로그램      1
# Name: service_type, dtype: int64

# %%
df.head(40)
# Out:
#    company       service                                    description  \
# 0     차오르다        클라우드스쿨                                 1:1 온라인 강의 서비스
# 1      트이다           트이다                           베트남 기반 한국어 회화 학습 서비스
# 2      플링크          페이지콜                          온디맨드 온라인 커뮤니케이션 소프트웨어
# 3   지란지교컴즈          쿨메신저  전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저
# 4       펍플            펍플                               클라우드기반 교육 출판 솔루션
# 5    스터디파이         스터디파이                                 온라인 스터디 중개 플랫폼
# 6    하얀마인드          레드키위                          영상기반 영어 말하기 연습용 모바일 앱
# 7    이십사점오            슥삭                  대외활동, 공모전, 서포터즈, 인턴, 동아리 추천 앱
# 8     키즈페이          키즈페이                 영업지사와 영유아 교육기관의 비대면 결제 관리 프로그램
# 9     단꿈아이          설쌤TV             한국사&인문학 기반 재미와 유익을 제공하는 컨텐츠 IP 서비스
# 10     유니브          연고티비                             교육/대학 전문 MCN 매니지먼트
# 11  러너스마인드         클래스카드                           영어쌤 1/3이 선택한 스마트 단어장
# 12    청그라미  아산 YMCA 청년센터                   충남 지역 사회혁신 창업교육 프로그램 및 공간 운영
# 13      플랭            플랭                            AI 스피킹, 영어회화 트레이닝 앱
# 14  이리온컴퍼니           이리온                  실시간으로 상호작용이 가능한 쌍방향 화상 교육 플랫폼
# 15      산타         디디캐스트                                   온라인 강의제작 솔루션
# 16    태인교육           파인듀                                      학원 정보 플랫폼
# 17      퀄슨           슈퍼팬                            미드, 영화로 배우는 영어 회화 앱
# 18    호두랩스        호두잉글리쉬                               스토리 기반의 영어 학습 게임
# 19     레드윗            구노                               블록체인 기반 연구노트 서비스
#
#    category1 category2 ir_total_amount  ir_stage funding_year_month  \
# 0         교육     과외/레슨             비공개      seed            2021-01
# 1         교육     외국어교육             비공개     pre-A            2021-01
# 2         교육      교육보조              42  series A            2021-01
# 3         교육       메신저              10  series A            2021-01
# 4         교육        도서               5      seed            2020-12
# 5         교육     과외/레슨              34  series A            2020-12
# 6         교육     외국어교육             7.5     pre-A            2020-12
# 7         교육      정보제공             1.5      seed            2020-12
# 8         교육     회계/세무             비공개      seed            2020-12
# 9         교육      대안교육              70  series A            2020-12
# 10        교육       MCN              25  series A            2020-11
# 11        교육     외국어교육             0.4      seed            2020-11
# 12        교육      기업지원             비공개      seed            2020-10
# 13        교육     외국어교육               5     pre-A            2020-10
# 14        교육      교육보조               2      seed            2020-10
# 15        교육    이미지/영상              38  series A            2020-10
# 16        교육        학원             비공개      seed            2020-10
# 17        교육     외국어교육             152  series B            2020-10
# 18        교육     외국어교육             155  series A            2020-10
# 19        교육     연구/실험              13       지원금            2020-09
#
#    funding_year         tech service_type
# 0          2021    음악/영상스트리밍         웹사이트
# 1          2021     이미지/영상제작         모바일앱
# 2          2021     이미지/영상처리         웹사이트
# 3          2021  리얼타임 커뮤니케이션         None
# 4          2020         클라우드        소프트웨어
# 5          2020  리얼타임 커뮤니케이션         웹사이트
# 6          2020    음악/영상스트리밍         모바일앱
# 7          2020           검색         모바일앱
# 8          2020         클라우드         웹사이트
# 9          2020     이미지/영상제작          콘텐츠
# 10         2020     이미지/영상제작       교육/컨설팅
# 11         2020      빅데이터/분석         모바일앱
# 12         2020          N/A         프로그램
# 13         2020         인공지능         None
# 14         2020    음악/영상스트리밍         웹사이트
# 15         2020         클라우드         웹사이트
# 16         2020           검색         웹사이트
# 17         2020    음악/영상스트리밍         모바일앱
# 18         2020         게임개발        소프트웨어
# 19         2020         블록체인         모바일앱

# %% [markdown]
# ### 정렬

# %%
#df = df.sort_values(by=['funding_year','ir_total_amount'], ascending=False)
#df.head(40)

# %%
# 파일로 저장하기

label = ["회사명","제품/서비스명","설명","대분류","소분류","총 투자금액","투자단계","투자연월","투자연도","기술","서비스 타입"]

df.to_excel("data_table.xlsx", index=False, header=label)
