# %% [markdown]
# - theVC는 크롤링을 의도적으로 막아놓았다.
#     - '스타트업 검색'에서 한번에 30개씩 로딩할 수 있다.
#     - 대분류/투자단계에 필터를 걸어도 url은 바뀌지 않으므로 request는 사용할 수 없다.
#     - selenium을 사용하려 하면, 제어되는 브라우저에서 로그인이 되지 않는다. (리캡차 무한반복)
# - 따라서 마우스드래그로 긁어 메모장에서 txt로 저장해 사용한다.

# %%
#from selenium import webdriver
#from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### text 파일 읽어오기

# %%
test = []

# %%
path = "../edu.txt"

with open(path, "r", encoding='UTF8') as file:
    strings = file.readlines()
    print(strings)
# Out:
# ['뤼이드\n', '한국∙스타트업\n', '산타토익\n', '머신러닝 기반 토익 학습 앱\n', '인공지능\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t6.8년\t120명\t125억\t844억\tseries D\t2020-07-23\t더보기 \n', '이루넷\n', '한국∙중소기업\n', '종로엠스쿨\n', '중학생 대상 학원\n', 'N/A\t교육\t학원\t공간\t창원시\t29.0년\t비공개\t200억\t200억\tseries D\t2010-02-19\t더보기 \n', '아발론교육\n', '한국∙중소기업\n', '아발론 잉글리쉬\n', '초등학생 영어 교육 서비스\n', '이미지/영상제작\t교육\t외국어교육\t웹사이트\t성남시\t17.9년\t365명\t660억\t660억\tseries D\t2008-07-03\t더보기 \n', '청담러닝\n', '한국∙중소기업\n', '청담어학원\n', '어학 전문 학원\n', 'N/A\t교육\t외국어교육\t공간\t서울특별시\t18.7년\t546명\t164억\t214억\tseries D\t2008-01-07\t더보기 \n', '뤼이드\n', '한국∙스타트업\n', '산타토익\n', '머신러닝 기반 토익 학습 앱\n', '인공지능\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t6.8년\t120명\t125억\t844억\tseries D\t2020-07-23\t더보기 \n', '에스티유니타스\n', '한국∙스타트업\n', '커넥츠 Q&A\n', '중/고등학교, 대학교, 경찰, 공무원 전과목 문제풀이 공부앱\n', '소셜네트워크\t교육\t정보제공\t웹사이트\t서울특별시\t10.9년\t676명\t1300억\t1529억\tseries C\t2020-06-08\t더보기 \n', '클래스팅\n', '한국∙스타트업\n', '클래스팅\n', '학교 정보 공유 및 교사 학부모 커뮤니케이션 서비스\n', '리얼타임 커뮤니케이션\t교육\t교육보조\t모바일앱-iOS\t서울특별시\t8.5년\t44명\t41억\t211억\tseries C\t2019-11-22\t더보기 \n', '단꿈아이\n', '한국∙스타트업\n', '설쌤TV\n', '한국사&인문학 기반 재미와 유익을 제공하는 컨텐츠 IP 서비스\n', '이미지/영상제작\t교육\t대안교육\t콘텐츠\t성남시\t1.4년\t52명\t20억\t70억\tseries A\t2020-12-08\t더보기 \n', '퀄슨\n', '한국∙스타트업\n', '슈퍼팬\n', '미드, 영화로 배우는 영어 회화 앱\n', '음악/영상스트리밍\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t8.6년\t91명\t75억\t152억\tseries B\t2020-10-14\t더보기 \n', '엘리스\n', '한국∙스타트업\n', '엘리스\n', '머신러닝 기반 온라인 소프트웨어 교육 플랫
'제이플', '한국∙스타트업', '키즈플', '어린이집과 유치원의 운영관리 프로그램', '프로그램개발\t유아\t유아교육\t웹사이트\t서울특별시\t2.8년\t3명\t5억\t5억\tpre-A\t2020-09-09\t더보기 ', '에이치투케이', '한국∙스타트업', '소중한글', '자모음의 소리와 조합원리를 깨우치는 소리중심교육법 (한글파닉스)을 적용시킨 한글교육 앱', '인공지능\t유아\t유아교육\t모바일앱-iOS\t대전광역시\t3.6년\t10명\t10억\t10억\tpre-A\t2020-09-07\t더보기 ', '스칸디에듀', '한국∙스타트업', '브레인나우', '영유아 두뇌자극 교육 콘텐츠', '이미지/영상제작\t유아\t유아교육\t상품\t서울특별시\t6.0년\t13명\t5억\t22억\tseries A\t2020-08-03\t더보기 ', '클레버 ...

# %%
company = []
service = []
description = []
detail = []

for i in range(0, len(test)):
    if i % 5 == 0:
        company.append(test[i])
    elif i % 5 == 2:
        service.append(test[i])
    elif i % 5 == 3:
        description.append(test[i])
    elif i % 5 == 4:
        detail.append(test[i])
    else:
        pass

print(company)
# Out:
# ['뤼이드', '이루넷', '아발론교육', '청담러닝', '뤼이드', '에스티유니타스', '클래스팅', '단꿈아이', '퀄슨', '엘리스', '뤼이드', '패스트캠퍼스', '에스티유니타스', '에누마', '럭스로보', '클래스팅', '매스프레소', '아이엔지스토리', '공부선배', '용감한컴퍼니', '플링크', '지란지교컴즈', '스터디파이', '단꿈아이', '유니브', '산타', '아우름플래닛', '오누이', '리버스랩', '패스트캠퍼스', '엔에이치엔에듀', '에스티유니타스', '에누마', '애드락애드버테인먼트', '플렉슬', '수파자', '클라썸', '클래스팅', '매스프레소', '아이엔지스토리', '공부선배', '퀄슨', '호두랩스', '뤼이드', '아이헤이트플라잉버그스', '링글잉글리시에듀케이션서비스', '캐치잇플레이', '엘리스', '코드잇', '럭스로보', '코드스테이츠', '디랩', '위즈스쿨', '골드래빗', '트이다', '스터디파이', '하얀마인드', '플랭', '산타', '레드윗', '하이코두', '아우름플래닛', '튜링', '지식팩토리', '에이아이파트너스', '리버스랩', '엔에이치엔에듀', '하이브', '칼라스컴퍼니', '주스', '플렉슬', '코딩로봇연구소', '클라썸', '아이헤이트플라잉버그스', '글로랑', '스마트잭', '플레인베이글', '포스픽', '티밸류와이즈', '캐치잇플레이', '매스프레소', '소프트데우스', '골드래빗', '용감한컴퍼니']

# %% [markdown]
# - 만약 깔끔하게 나오지 않는다면, 별도 행으로 '더보기'가 들어간 것이다.
# - txt 파일에서 지워줘야 함

# %%
print(description)
# Out:
# ['머신러닝 기반 토익 학습 앱', '중학생 대상 학원', '초등학생 영어 교육 서비스', '어학 전문 학원', '머신러닝 기반 토익 학습 앱', '중/고등학교, 대학교, 경찰, 공무원 전과목 문제풀이 공부앱', '학교 정보 공유 및 교사 학부모 커뮤니케이션 서비스', '한국사&인문학 기반 재미와 유익을 제공하는 컨텐츠 IP 서비스', '미드, 영화로 배우는 영어 회화 앱', '머신러닝 기반 온라인 소프트웨어 교육 플랫폼', '머신러닝 기반 토익 학습 앱', '직장인, 성인 실무교육 서비스', '중/고등학교, 대학교, 경찰, 공무원 전과목 문제풀이 공부앱', '초등학생용 게임기반 수학 학습 앱', '모듈형 로보틱스 플랫폼', '학교 정보 공유 및 교사 학부모 커뮤니케이션 서비스', '인공지능기반 수학 문제 풀이 앱', '프리미엄 독서실 브랜드', '학원 비교 검색 서비스', '공무원시험 준비 인터넷 강의 서비스', '온디맨드 온라인 커뮤니케이션 소프트웨어', '전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저', '온라인 스터디 중개 플랫폼', '한국사&인문학 기반 재미와 유익을 제공하는 컨텐츠 IP 서비스', '교육/대학 전문 MCN 매니지먼트', '온라인 강의제작 솔루션', '웹에 하이라이팅을 남길 수 있는 서비스', '아이패드 기반 서울대생 과외 서비스', '학원차량 공유 서비스', '직장인, 성인 실무교육 서비스', '학교 정보 공유 및 교사 학부모 커뮤니케이션 서비스', '중/고등학교, 대학교, 경찰, 공무원 전과목 문제풀이 공부앱', '초등학생용 게임기반 수학 학습 앱', '운전면허 필기시험 공부 앱', '디지털 노트를 결합한, iPad와 클라우드 기반의 학습 도구', '1:1 맞춤 서울대선생님의 화상수업 플랫폼', '수업 별 소통 플랫폼', '학교 정보 공유 및 교사 학부모 커뮤니케이션 서비스', '인공지능기반 수학 문제 풀이 앱', '프리미엄 독서실 브랜드', '학원 비교 검색 서비스', '미드, 영화로 배우는 영어 회화 앱', '스토리 기반의 영어 학습 게임', '머신러닝 기반 토익 학습 앱', '공무원 영단어 집중관리 시스템', '1대1 온라인 영어회화 튜터링 서비스', '영어학습용 게임 서비스', '머신러닝 기반 온라인 소프트웨어 교육 플랫폼', '온라인 프로그래밍 교육 서비스', '모듈형 로보틱스 플랫폼', '무료로 20주만에 소프트웨어 분야로 커리어 전환할 수 있는 코딩 부트캠프', '초중고학생을 대상으로한 소프트웨어 교육 아카데미', '컴파일러 기술을 활용안 AI 튜터 기반의 코딩 교육 플랫폼', '무선 코딩 블록 키트', '베트남 기반 한국어 회화 학습 서비스', '온라인 스터디 중개 플랫폼', '영상기반 영어 말하기 연습용 모바일 앱', 'AI 스피킹, 영어회화 트레이닝 앱', '온라인 강의제작 솔루션', '블록체인 기반 연구노트 서비스', 'SW&AI 교육용 플랫폼', '웹에 하이라이팅을 남길 수 있는 서비스', '인공지능(AI) 기반 온라인 수학 교육 서비스', '진로진학컨설팅 플랫폼', '인공지능 무료 대입 정시 예측 플랫폼', '학원차량 공유 서비스', '학교 정보 공유 및 교사 학부모 커뮤니케이션 서비스', '숏 비디오 형태로 외국어를 공부하는 서비스', '학습자 빅데이터 기반 인공지능 비즈니스 영어 토탈케어 시스템', '음대 입시생들을 위한 온라인 청음 레슨 서비스', '디지털 노트를 결합한, iPad와 클라우드 기반의 학습 도구', '코딩 학습 관리 시스템', '수업 별 소통 플랫폼', '공무원 영단어 집중관리 시스템', '유학/워킹홀리데이/어학연수 커뮤니티 서비스', '물품 / 안전 / 행정 / HR 관리 기능을 제공하는 연구실 토탈 관리 솔루션', '동영상 기반 고객 맞춤 언어학습 자동화 솔루션', '어학 도서 플랫폼', '학생, 강사, 학원을 위한 강사 리뷰 플랫폼', '영어학습용 게임 서비스', '인공지능기반 수학 문제 풀이 앱', '초 중학생 대상 코딩교육, 고교 성년 고급 코딩 교육', '무선 코딩 블록 키트', '공무원시험 준비 인터넷 강의 서비스']

# %%
# 리스트별 개수가 맞는지 확인

print(len(company))
print(len(service))
print(len(description))
print(len(detail))
# Out:
# 84
# 84
# 84
# 84

# %% [markdown]
# ### 데이터프레임으로 합치기

# %%
# 데이터프레임으로 저장하기
import pandas as pd 

df = []

zippedList = list(zip(company, service, description, detail))

df= pd.DataFrame(zippedList, columns = ['company', 'service', 'description', 'detail'])

df.tail()
# Out:
#    company  service                    description  \
# 79  캐치잇플레이  캐치잇잉글리시                   영어학습용 게임 서비스
# 80   매스프레소       콴다              인공지능기반 수학 문제 풀이 앱
# 81  소프트데우스    코딩 교육  초 중학생 대상 코딩교육, 고교 성년 고급 코딩 교육
# 82    골드래빗      마운지                    무선 코딩 블록 키트
# 83  용감한컴퍼니   모두의공무원            공무원시험 준비 인터넷 강의 서비스
#
#                                                detail
# 79  게임개발\t교육\t외국어교육\t모바일앱-Android\t제주시\t4.8년\t18명\...
# 80  인공지능\t교육\t수학교육\t모바일앱-iOS\t서울특별시\t5.6년\t125명\t4...
# 81  프로그램개발\t교육\t프로그램개발\t소프트웨어\t서울특별시\t2.7년\t3명\t10...
# 82  사물인터넷/센서\t교육\t프로그램개발\t하드웨어\t부산광역시\t7.9년\t8명\t7...
# 83  이미지/영상제작\t교육\t학원\t모바일앱-iOS\t서울특별시\t9.1년\t78명\t...

# %% [markdown]
# ### detail 정보 분리하기

# %%
df_raw = df

# %%
# 대분류
def split_desc(detail):
    return detail.split("\t")[1]

df['category1'] = df['detail'].apply(split_desc)

# 소분류
def split_desc(detail):
    return detail.split("\t")[2]

df['category2'] = df['detail'].apply(split_desc)

# 총 투자금액
def split_desc(detail):
    return detail.split("\t")[8]

df['ir_total_amount'] = df['detail'].apply(split_desc)

# 현재 투자단계
def split_desc(detail):
    return detail.split("\t")[9]

df['ir_stage'] = df['detail'].apply(split_desc)

# 최근 투자날짜
def split_desc(detail):
    return detail.split("\t")[10]

df['ir_date'] = df['detail'].apply(split_desc)

# %%
# 연도만 추출
df['funding_year_month'] = df['ir_date'].str[0:7]
df['funding_year'] = df['ir_date'].str[0:4]
df.head()
# Out:
#   company   service      description  \
# 0     뤼이드      산타토익  머신러닝 기반 토익 학습 앱
# 1     이루넷     종로엠스쿨        중학생 대상 학원
# 2   아발론교육  아발론 잉글리쉬   초등학생 영어 교육 서비스
# 3    청담러닝     청담어학원         어학 전문 학원
# 4     뤼이드      산타토익  머신러닝 기반 토익 학습 앱
#
#                                               detail category1 category2  \
# 0  인공지능\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t6.8년\t120명\t...        교육     외국어교육
# 1  N/A\t교육\t학원\t공간\t창원시\t29.0년\t비공개\t200억\t200억\t...        교육        학원
# 2  이미지/영상제작\t교육\t외국어교육\t웹사이트\t성남시\t17.9년\t365명\t6...        교육     외국어교육
# 3  N/A\t교육\t외국어교육\t공간\t서울특별시\t18.7년\t546명\t164억\t...        교육     외국어교육
# 4  인공지능\t교육\t외국어교육\t모바일앱-iOS\t서울특별시\t6.8년\t120명\t...        교육     외국어교육
#
#   ir_total_amount  ir_stage     ir_date funding_year_month funding_year
# 0            844억  series D  2020-07-23            2020-07         2020
# 1            200억  series D  2010-02-19            2010-02         2010
# 2            660억  series D  2008-07-03            2008-07         2008
# 3            214억  series D  2008-01-07            2008-01         2008
# 4            844억  series D  2020-07-23            2020-07         2020

# %%
# 나머지 정보 붙이기 : 기술, 서비스 타입

# 기술
def split_desc(detail):
    return detail.split("\t")[0]

df['tech'] = df['detail'].apply(split_desc)

# 서비스 형태
def split_desc(detail):
    return detail.split("\t")[3]

df['service_type'] = df['detail'].apply(split_desc)

# %%
# detail 컬럼 지우기
df.drop('detail', axis=1, inplace=True)
df.head()
# Out:
#   company   service      description category1 category2 ir_total_amount  \
# 0     뤼이드      산타토익  머신러닝 기반 토익 학습 앱        교육     외국어교육            844억
# 1     이루넷     종로엠스쿨        중학생 대상 학원        교육        학원            200억
# 2   아발론교육  아발론 잉글리쉬   초등학생 영어 교육 서비스        교육     외국어교육            660억
# 3    청담러닝     청담어학원         어학 전문 학원        교육     외국어교육            214억
# 4     뤼이드      산타토익  머신러닝 기반 토익 학습 앱        교육     외국어교육            844억
#
#    ir_stage     ir_date funding_year_month funding_year      tech service_type
# 0  series D  2020-07-23            2020-07         2020      인공지능     모바일앱-iOS
# 1  series D  2010-02-19            2010-02         2010       N/A           공간
# 2  series D  2008-07-03            2008-07         2008  이미지/영상제작         웹사이트
# 3  series D  2008-01-07            2008-01         2008       N/A           공간
# 4  series D  2020-07-23            2020-07         2020      인공지능     모바일앱-iOS

# %% [markdown]
# ### 투자금액을 숫자로 변환하기

# %%
# O천만원 -> 억으로 변환

def transform(amount):
    if "천만원" in amount:
        amount = amount.replace("천만원", "")
        amount = int(amount) * 0.1
    return amount
    
    
df['ir_total_amount'] = df['ir_total_amount'].apply(transform)

df['ir_total_amount'].str.contains("천만원").sum()
# Out:
# 0

# %%
# 텍스트 제거 -> 투자금액 숫자형으로 변환

df['ir_total_amount'] = df['ir_total_amount'].str.replace("억", "")
df['ir_total_amount'] = df['ir_total_amount'].str.replace("비공개", "0")

df['ir_total_amount'] = pd.to_numeric(df['ir_total_amount'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   company             84 non-null     object
#  1   service             84 non-null     object
#  2   description         84 non-null     object
#  3   category1           84 non-null     object
#  4   category2           84 non-null     object
#  5   ir_total_amount     82 non-null     float64
#  6   ir_stage            84 non-null     object
#  7   ir_date             84 non-null     object
#  8   funding_year_month  84 non-null     object
#  9   funding_year        84 non-null     object
#  10  tech                84 non-null     object
#  11  service_type        84 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 8.0+ KB

# %%
df.head()
# Out:
#   company   service      description category1 category2  ir_total_amount  \
# 0     뤼이드      산타토익  머신러닝 기반 토익 학습 앱        교육     외국어교육            844.0
# 1     이루넷     종로엠스쿨        중학생 대상 학원        교육        학원            200.0
# 2   아발론교육  아발론 잉글리쉬   초등학생 영어 교육 서비스        교육     외국어교육            660.0
# 3    청담러닝     청담어학원         어학 전문 학원        교육     외국어교육            214.0
# 4     뤼이드      산타토익  머신러닝 기반 토익 학습 앱        교육     외국어교육            844.0
#
#    ir_stage     ir_date funding_year_month funding_year      tech service_type
# 0  series D  2020-07-23            2020-07         2020      인공지능     모바일앱-iOS
# 1  series D  2010-02-19            2010-02         2010       N/A           공간
# 2  series D  2008-07-03            2008-07         2008  이미지/영상제작         웹사이트
# 3  series D  2008-01-07            2008-01         2008       N/A           공간
# 4  series D  2020-07-23            2020-07         2020      인공지능     모바일앱-iOS

# %%
df.shape
# Out:
# (84, 12)

# %% [markdown]
# ### 중복 업체 제거

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (56, 12)

# %% [markdown]
# ### 정렬

# %%
df = df.sort_values(by=['funding_year','ir_total_amount'], ascending=False)

# %%
df.head(40)
# Out:
#         company    service                                    description  \
# 20          플링크       페이지콜                          온디맨드 온라인 커뮤니케이션 소프트웨어
# 21       지란지교컴즈       쿨메신저  전국 25만여 명의 초·중·고교의 교사와 교직원들이 사용하는 학사업무 전용 메신저
# 54          트이다        트이다                           베트남 기반 한국어 회화 학습 서비스
# 5       에스티유니타스    커넥츠 Q&A              중/고등학교, 대학교, 경찰, 공무원 전과목 문제풀이 공부앱
# 0           뤼이드       산타토익                                머신러닝 기반 토익 학습 앱
# 11       패스트캠퍼스     패스트캠퍼스                               직장인, 성인 실무교육 서비스
# 30      엔에이치엔에듀      아이엠스쿨                   학교 정보 공유 및 교사 학부모 커뮤니케이션 서비스
# 13          에누마       토도수학                             초등학생용 게임기반 수학 학습 앱
# 42         호두랩스     호두잉글리쉬                               스토리 기반의 영어 학습 게임
# 8            퀄슨        슈퍼팬                            미드, 영화로 배우는 영어 회화 앱
# 14         럭스로보         모디                                   모듈형 로보틱스 플랫폼
# 9           엘리스        엘리스                       머신러닝 기반 온라인 소프트웨어 교육 플랫폼
# 7          단꿈아이       설쌤TV             한국사&인문학 기반 재미와 유익을 제공하는 컨텐츠 IP 서비스
# 26       아우름플래닛        라이너                          웹에 하이라이팅을 남길 수 있는 서비스
# 48          코드잇        코드잇                               온라인 프로그래밍 교육 서비스
# 25           산타      디디캐스트                                   온라인 강의제작 솔루션
# 28         리버스랩      옐로우버스                                    학원차량 공유 서비스
# 22        스터디파이      스터디파이                                 온라인 스터디 중개 플랫폼
# 24          유니브       연고티비                             교육/대학 전문 MCN 매니지먼트
# 27          오누이         설탭                            아이패드 기반 서울대생 과외 서비스
# 33   애드락애드버테인먼트  운전면허 PLUS                                 운전면허 필기시험 공부 앱
# 62           튜링       수학대왕                      인공지능(AI) 기반 온라인 수학 교육 서비스
# 59          레드윗         구노                               블록체인 기반 연구노트 서비스
# 56        하얀마인드       레드키위                          영상기반 영어 말하기 연습용 모바일 앱
# 57           플랭         플랭                            AI 스피킹, 영어회화 트레이닝 앱
# 69           주스       청음이지                      음대 입시생들을 위한 온라인 청음 레슨 서비스
# 67          하이브        하이비                        숏 비디오 형태로 외국어를 공부하는 서비스
# 64     에이아이파트너스       대입하다                           인공지능 무료 대입 정시 예측 플랫폼
# 63        지식팩토리         잡썰                                    진로진학컨설팅 플랫폼
# 60         하이코두         수프                                  SW&AI 교육용 플랫폼
# 50       코드스테이츠     코드스테이츠       무료로 20주만에 소프트웨어 분야로 커리어 전환할 수 있는 코딩 부트캠프
# 68       칼라스컴퍼니        칼라스              학습자 빅데이터 기반 인공지능 비즈니스 영어 토탈케어 시스템
# 16        매스프레소         콴다                              인공지능기반 수학 문제 풀이 앱
# 6          클래스팅       클래스팅                   학교 정보 공유 및 교사 학부모 커뮤니케이션 서비스
# 17      아이엔지스토리      작심독서실                                   프리미엄 독서실 브랜드
# 18         공부선배       공부선배                                   학원 비교 검색 서비스
# 46       캐치잇플레이    캐치잇잉글리시                                   영어학습용 게임 서비스
# 19       용감한컴퍼니     모두의공무원                            공무원시험 준비 인터넷 강의 서비스
# 52         위즈스쿨       위즈스쿨               컴파일러 기술을 활용안 AI 튜터 기반의 코딩 교육 플랫폼
# 44  아이헤이트플라잉버그스       밀당영어                               공무원 영단어 집중관리 시스템
#
#    category1 category2  ir_total_amount  ir_stage     ir_date  \
# 20        교육      교육보조             42.0  series A  2021-01-05
# 21        교육       메신저             10.0  series A  2021-01-04
# 54        교육     외국어교육              0.0     pre-A  2021-01-22
# 5         교육      정보제공           1529.0  series C  2020-06-08
# 0         교육     외국어교육            844.0  series D  2020-07-23
# 11        교육   직무교육/개발            315.0  series B  2020-06-30
# 30        교육      교육보조            181.0  series A  2020-06-22
# 13        교육      수학교육            160.0  series B  2020-05-18
# 42        교육     외국어교육            155.0  series A  2020-10-06
# 8         교육     외국어교육            152.0  series B  2020-10-14
# 14        교육    프로그램개발            150.0  series B  2020-02-17
# 9         교육    프로그램개발            134.0  series B  2020-09-24
# 7         교육      대안교육             70.0  series A  2020-12-08
# 26        교육      교육보조             62.0  series A  2020-08-28
# 48        교육    프로그램개발             40.0  series A  2020-04-01
# 25        교육    이미지/영상             38.0  series A  2020-10-19
# 28        교육        학원             36.0  series A  2020-06-30
# 22        교육     과외/레슨             34.0  series A  2020-12-30
# 24        교육       MCN             25.0  series A  2020-11-11
# 27        교육     과외/레슨             21.0  series A  2020-08-03
# 33        교육    면허/자격증             15.0  series A  2020-03-16
# 62        교육      수학교육             15.0     pre-A  2020-08-05
# 59        교육     연구/실험             13.0       지원금  2020-09-25
# 56        교육     외국어교육              7.5     pre-A  2020-12-29
# 57        교육     외국어교육              5.0     pre-A  2020-10-26
# 69        교육       클래식              5.0       지원금  2020-02-01
# 67        교육     외국어교육              3.6     pre-A  2020-06-15
# 64        교육       컨설팅              2.2      seed  2020-07-06
# 63        교육       컨설팅              1.0     pre-A  2020-07-31
# 60        교육    프로그램개발              0.0      seed  2020-09-10
# 50        교육    프로그램개발              NaN  series A  2020-02-10
# 68        교육     외국어교육              NaN      seed  2020-03-09
# 16        교육      수학교육            252.0  series B  2019-07-01
# 6         교육      교육보조            211.0  series C  2019-11-22
# 17        교육       독서실            205.0  series B  2019-05-29
# 18        교육        학원             54.0  series B  2019-03-08
# 46        교육     외국어교육             45.0  series A  2019-07-24
# 19        교육        학원             43.0  series B  2019-01-04
# 52        교육    프로그램개발             30.0  series A  2019-10-24
# 44        교육     외국어교육             25.0  series A  2019-12-01
#
#    funding_year_month funding_year         tech  service_type
# 20            2021-01         2021     이미지/영상처리          웹사이트
# 21            2021-01         2021  리얼타임 커뮤니케이션          None
# 54            2021-01         2021     이미지/영상제작      모바일앱-iOS
# 5             2020-06         2020       소셜네트워크          웹사이트
# 0             2020-07         2020         인공지능      모바일앱-iOS
# 11            2020-06         2020    음악/영상스트리밍          웹사이트
# 30            2020-06         2020  리얼타임 커뮤니케이션      모바일앱-iOS
# 13            2020-05         2020         게임개발      모바일앱-iOS
# 42            2020-10         2020         게임개발         소프트웨어
# 8             2020-10         2020    음악/영상스트리밍      모바일앱-iOS
# 14            2020-02         2020     사물인터넷/센서          하드웨어
# 9             2020-09         2020         인공지능          웹사이트
# 7             2020-12         2020     이미지/영상제작           콘텐츠
# 26            2020-08         2020       소셜네트워크      모바일앱-iOS
# 48            2020-04         2020    음악/영상스트리밍          웹사이트
# 25            2020-10         2020         클라우드          웹사이트
# 28            2020-06         2020  리얼타임 커뮤니케이션      모바일앱-iOS
# 22            2020-12         2020  리얼타임 커뮤니케이션          웹사이트
# 24            2020-11         2020     이미지/영상제작        교육/컨설팅
# 27            2020-08         2020  리얼타임 커뮤니케이션      모바일앱-iOS
# 33            2020-03         2020           검색      모바일앱-iOS
# 62            2020-08         2020         인공지능          웹사이트
# 59            2020-09         2020         블록체인      모바일앱-iOS
# 56            2020-12         2020    음악/영상스트리밍      모바일앱-iOS
# 57            2020-10         2020         인공지능          None
# 69            2020-02         2020    음악/영상스트리밍          웹사이트
# 67            2020-06         2020       소셜네트워크      모바일앱-iOS
# 64            2020-07         2020         인공지능  모바일앱-Android
# 63            2020-07         2020         인공지능          웹사이트
# 60            2020-09         2020       프로그램개발         소프트웨어
# 50            2020-02         2020       프로그램개발        교육/컨설팅
# 68            2020-03         2020    음악/영상스트리밍  모바일앱-Android
# 16            2019-07         2019         인공지능      모바일앱-iOS
# 6             2019-11         2019  리얼타임 커뮤니케이션      모바일앱-iOS
# 17            2019-05         2019          N/A            공간
# 18            2019-03         2019           검색      모바일앱-iOS
# 46            2019-07         2019         게임개발  모바일앱-Android
# 19            2019-01         2019     이미지/영상제작      모바일앱-iOS
# 52            2019-10         2019         인공지능      모바일앱-iOS
# 44            2019-12         2019       프로그램개발      모바일앱-iOS

# %%
# 파일로 저장하기
import pandas as pd
label = ["회사명","제품/서비스명","설명","대분류","소분류","총 투자금액","투자단계","최근 투자날짜","투자연월", "투자연도","기술","서비스 타입"]

df.to_excel("../edu.xlsx", index=False, header=False)

# %%
# 드라이버 종료
chrome.quit()
