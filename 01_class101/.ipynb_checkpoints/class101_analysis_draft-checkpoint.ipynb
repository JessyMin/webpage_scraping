# %%
import pandas as pd
df = pd.read_csv("class101_20200714.csv", index_col=False)

# %%
df.head()
# Out:
#    Unnamed: 0             header                                   title  \
# 0           0     부업/창업/재테크・신사임당  스마트스토어로 월 100만원 만들기, 평범한 사람이 돈을 만드는 비법
# 1           1              미술・둡         연필 하나만으로 모든 분위기를 담아내요, 둡의 연필 드로잉
# 2           2  미술・Findenart 핀든아트        여행 드로잉, 꿈만 꾸지 마세요. 핀든아트와 여행, 그리다
# 3           3        디지털 드로잉・반지수   일상에 따뜻한 숨결을 불어넣어요, 반지수와 함께하는 아이패드 드로잉
# 4           4        미술・집시 zipcy                일러스트레이터 집시의 매력적인 얼굴 그리기
#
#    favorite      price   category         creator
# 0     18974  월 53,520원  부업/창업/재테크            신사임당
# 1     18190  월 39,900원         미술              둡
# 2     16646  월 59,900원         미술  Findenart 핀든아트
# 3     15509  월 44,900원    디지털 드로잉             반지수
# 4     13560  월 49,900원         미술        집시 zipcy

# %%
df = df.drop(['Unnamed: 0', 'header'], axis=1)
df.head()
# Out:
#                                     title  favorite      price   category  \
# 0  스마트스토어로 월 100만원 만들기, 평범한 사람이 돈을 만드는 비법     18974  월 53,520원  부업/창업/재테크
# 1        연필 하나만으로 모든 분위기를 담아내요, 둡의 연필 드로잉     18190  월 39,900원         미술
# 2        여행 드로잉, 꿈만 꾸지 마세요. 핀든아트와 여행, 그리다     16646  월 59,900원         미술
# 3   일상에 따뜻한 숨결을 불어넣어요, 반지수와 함께하는 아이패드 드로잉     15509  월 44,900원    디지털 드로잉
# 4                일러스트레이터 집시의 매력적인 얼굴 그리기      13560  월 49,900원         미술
#
#           creator
# 0            신사임당
# 1              둡
# 2  Findenart 핀든아트
# 3             반지수
# 4        집시 zipcy

# %%
df.shape
# Out:
# (903, 5)

# %%
# 좋아요가 500개 이상인 데이터만 추출
df_over_1000 = df[df.favorite > 1000]
df_over_1000.shape
# Out:
# (524, 5)

# %%
# 좋아요가 4300개 이상인 데이터만 추출 (상위 10%)
df_over_4300 = df[df.favorite > 4300]
df_over_4300.shape
# Out:
# (97, 5)

# %%
df['category'].isna().sum()
# Out:
# 0

# %%
df['category'].value_counts()
# Out:
# 공예           214
# 미술           165
# 디지털 드로잉      112
# 부업/창업/재테크     57
# 요리/음료         54
# 라이프 스타일       50
# 디자인/개발        48
# EASY DIY      45
# 사진/영상         44
# 직무            23
# 음악            22
# 시그니처          16
# 굿즈            15
# 미술재료          10
# 디지털기기/ACC      7
# 자기계발           5
# 공예재료           4
# 악기/음악          3
# 운동             3
# 커리어            2
# 문구/도서          2
# 푸드/키친          1
# 헬스/뷰티/ACC      1
# Name: category, dtype: int64

# %%
df_over_1000['category'].value_counts()
# Out:
# 공예           133
# 미술           112
# 디지털 드로잉       83
# 요리/음료         40
# 사진/영상         31
# 디자인/개발        31
# 라이프 스타일       28
# 부업/창업/재테크     28
# 음악            12
# 시그니처          10
# 직무             9
# 자기계발           2
# EASY DIY       2
# 미술재료           1
# 운동             1
# 디지털기기/ACC      1
# Name: category, dtype: int64

# %%
df_over_4300['category'].value_counts()
# Out:
# 디지털 드로잉      26
# 미술           23
# 공예           15
# 사진/영상         9
# 부업/창업/재테크     8
# 디자인/개발        6
# 요리/음료         6
# 라이프 스타일       2
# 시그니처          1
# 음악            1
# Name: category, dtype: int64

# %%
# 전체 강의 중 디지털드로잉 추출
df_ddrawing = df[df['category'] == '디지털 드로잉']
df_ddrawing.shape
# Out:
# (112, 5)

# %%
df_ddrawing.head(10)
# Out:
#                 header                                     title  favorite  \
# 3          디지털 드로잉・반지수     일상에 따뜻한 숨결을 불어넣어요, 반지수와 함께하는 아이패드 드로잉     15509
# 17        디지털 드로잉・그리지영          나만의 문방구를 차려요! 그리지영의 타블렛으로 굿즈 만들기      7770
# 18        디지털 드로잉・사심굿즈             취미를 넘어 굿즈 셀러로! 인쇄물 굿즈 제작과 상품화      7669
# 21        디지털 드로잉・그림바지              새로운 드로잉 기법의 설렘, 레트로 픽셀아트 드로잉      7277
# 25         디지털 드로잉・그림비               일러스트레이터 배성태(그림비)의 달달한 일상드로잉      7201
# 28        디지털 드로잉・별라랜드             차근차근, 아이패드로 그리는 미니멀한 손그림 일러스트      6952
# 38         디지털 드로잉・배성규            배성규 작가와 함께 아이패드로 그리는 스물네 번의 보름      6172
# 40          디지털 드로잉・우동  소중한 기억에 나만의 색을 칠하다 - 일러스트레이터 우동의 디지털 페인팅      6057
# 41          디지털 드로잉・캣빵                 아이패드로 시작하는 캣빵의 귀여운 굿즈 만들기      6039
# 43  디지털 드로잉・키츠 (kits.)              아이패드 하나로 떠나는 키츠의 아날로그 텍스처 여행      5770
#
#         price category     creator
# 3   월 44,900원  디지털 드로잉         반지수
# 17  월 30,400원  디지털 드로잉        그리지영
# 18  월 39,900원  디지털 드로잉        사심굿즈
# 21  월 31,960원  디지털 드로잉        그림바지
# 25  월 42,720원  디지털 드로잉         그림비
# 28  월 42,500원  디지털 드로잉        별라랜드
# 38  월 51,880원  디지털 드로잉         배성규
# 40  월 46,150원  디지털 드로잉          우동
# 41  월 43,880원  디지털 드로잉          캣빵
# 43  월 24,880원  디지털 드로잉  키츠 (kits.)

# %% [markdown]
# ## 수익, 굿즈, 이모티콘 관련 클래스 추출하기

# %%
df[df['title'].str.contains('수익')]
# Out:
#                                                  title  favorite       price  \
# 10                        블로그로 하루 2시간 투자해서 직장인만큼 수익내기!      9226   월 45,632원
# 34                    15만 유튜버 자청의 자동수익 월 1,000만원 만드는 법      6443  월 111,298원
# 83                   월세 수익 300만 원을 만드는 송사무장의 부동산 투자법!       4474   월 27,740원
# 181             월 100만원 수익! 아이디어스, 스마트스토어에서 월급 외 수익 벌기      3035   월 43,058원
# 505             쿠팡 파트너스와 제휴 마케팅으로 집에서 월 200만 원 부수익 만들기      1069   월 43,058원
# 542                 만화로 수익 창출까지! 난희의 아이패드로 SNS 웹툰 그려보기       937   월 46,440원
# 544                         소소하지만 확실하게, 이모티콘으로 수익 창출하기       934   월 34,900원
# 567                 프리랜서로 N개의 직업을 가지며, 나만의 수익을 만드는 방법!       865   월 48,848원
# 575  내 스마트스토어 상품을 해외에 파는 법 : 쇼피파이로 매일 2시간 투자해서 수익 불리기!       838   월 52,984원
# 599         연봉 1억 유튜버가 도와주는 유튜버 되는 지름길, 채널 생성부터 수익화까지!       778   월 49,758원
# 684                스타트업 투자로 재테크하라! 10배 수익 내는 비상장 주식 투자       556   월 45,632원
# 686                         처음 하는 주식 투자, 연 20% 수익 내는 법       550   월 52,984원
# 744                              네이버 블로그 체험단 수익 1억 만들기       407   월 49,520원
# 842       구독자 175만 진용진이 알려드립니다. 진짜 현실적으로 유튜브 수익창출하는 법!       218   월 25,740원
#
#       category      creator
# 10   부업/창업/재테크       리뷰요정리남
# 34   부업/창업/재테크    라이프 해커 자청
# 83   부업/창업/재테크         송사무장
# 181  부업/창업/재테크          단아쌤
# 505  부업/창업/재테크  1프로마케터  서동민
# 542    디지털 드로잉           난희
# 544    디지털 드로잉           수팡
# 567  부업/창업/재테크       코스모지나
# 575  부업/창업/재테크          온도남
# 599  부업/창업/재테크         구스마일
# 684  부업/창업/재테크         대한팀장
# 686  부업/창업/재테크     절대수익 이재웅
# 744  부업/창업/재테크       다퍼주는남자
# 842        커리어          진용진

# %%
# 해당되는 클래스의 갯수
df['title'].str.contains('수익').sum()
# Out:
# 14

# %%
df[df['title'].str.contains('굿즈')]
# Out:
#                                                title  favorite      price  \
# 17                  나만의 문방구를 차려요! 그리지영의 타블렛으로 굿즈 만들기      7770  월 30,400원
# 18                     취미를 넘어 굿즈 셀러로! 인쇄물 굿즈 제작과 상품화      7669  월 39,900원
# 41                         아이패드로 시작하는 캣빵의 귀여운 굿즈 만들기      6039  월 43,880원
# 71                     일러스트레이터 이공과 함께 나만의 미니 굿즈 제작하기      4907  월 35,900원
# 121                   소소하지만 확실한 행복, 유르의 굿즈 제작부터 판매까지      3905  월 36,900원
# 155                    실로 그리는 그림, 스왈로우굿즈의 일러스트 프랑스자수      3365  월 46,900원
# 186                       전구별과 떠나는 캐릭터 제작과 굿즈 만들기 세상      2996  월 43,046원
# 199                     별별그림의 실크스크린으로 쓱싹 만드는 유니크한 굿즈      2876  월 43,900원
# 213                          귀염뽀짝 일러스트 굿즈 만들기의 모든 것!      2794  월 43,880원
# 284                  내가 그린 캐릭터로 브랜드 시작하기! 굿즈부터 사업화까지      2169  월 49,676원
# 299  아이패드 드로잉의 기초부터 굿즈 제작까지, 따뜻하고 몽글몽글하게 흐스흐와 함께 해요!      2074  월 44,280원
# 364       내가 만든 수공예품, 그림 굿즈, 디지털 파일 판매로 엣시에서 돈 버는 법!      1726  월 45,632원
# 560                        [꿀조합 할인🍯] 귀염뽀짝한 굿즈 제작 입문편       880  월 29,908원
# 627                  잠들어 있던 사진첩 속 사진들로 나만의 굿즈를 만들어봐요       686  월 40,220원
# 837                약국의 센티멘탈 감성이 짙게 묻은 굿즈, 최대 40% 할인!       228    10,450원
#
#       category          creator
# 17     디지털 드로잉             그리지영
# 18     디지털 드로잉             사심굿즈
# 41     디지털 드로잉               캣빵
# 71     디지털 드로잉               이공
# 121    디지털 드로잉               유르
# 155         공예           스왈로우굿즈
# 186    디지털 드로잉              전구별
# 199         공예             별별그림
# 213    디지털 드로잉          뽐뽐 스튜디오
# 284  부업/창업/재테크               효샤
# 299    디지털 드로잉              흐스흐
# 364  부업/창업/재테크  미돌남 - 미싱 돌리는 남자
# 560    디지털 드로잉           클래스101
# 627     디자인/개발             포그보우
# 837         굿즈           클래스101

# %% [markdown]
# ### '굿즈' 키워드 포함하는 클래스

# %%
df[df['title'].str.contains('굿즈')]
# Out:
#                                                title  favorite      price  \
# 17                  나만의 문방구를 차려요! 그리지영의 타블렛으로 굿즈 만들기      7770  월 30,400원
# 18                     취미를 넘어 굿즈 셀러로! 인쇄물 굿즈 제작과 상품화      7669  월 39,900원
# 41                         아이패드로 시작하는 캣빵의 귀여운 굿즈 만들기      6039  월 43,880원
# 71                     일러스트레이터 이공과 함께 나만의 미니 굿즈 제작하기      4907  월 35,900원
# 121                   소소하지만 확실한 행복, 유르의 굿즈 제작부터 판매까지      3905  월 36,900원
# 155                    실로 그리는 그림, 스왈로우굿즈의 일러스트 프랑스자수      3365  월 46,900원
# 186                       전구별과 떠나는 캐릭터 제작과 굿즈 만들기 세상      2996  월 43,046원
# 199                     별별그림의 실크스크린으로 쓱싹 만드는 유니크한 굿즈      2876  월 43,900원
# 213                          귀염뽀짝 일러스트 굿즈 만들기의 모든 것!      2794  월 43,880원
# 284                  내가 그린 캐릭터로 브랜드 시작하기! 굿즈부터 사업화까지      2169  월 49,676원
# 299  아이패드 드로잉의 기초부터 굿즈 제작까지, 따뜻하고 몽글몽글하게 흐스흐와 함께 해요!      2074  월 44,280원
# 364       내가 만든 수공예품, 그림 굿즈, 디지털 파일 판매로 엣시에서 돈 버는 법!      1726  월 45,632원
# 560                        [꿀조합 할인🍯] 귀염뽀짝한 굿즈 제작 입문편       880  월 29,908원
# 627                  잠들어 있던 사진첩 속 사진들로 나만의 굿즈를 만들어봐요       686  월 40,220원
# 837                약국의 센티멘탈 감성이 짙게 묻은 굿즈, 최대 40% 할인!       228    10,450원
#
#       category          creator
# 17     디지털 드로잉             그리지영
# 18     디지털 드로잉             사심굿즈
# 41     디지털 드로잉               캣빵
# 71     디지털 드로잉               이공
# 121    디지털 드로잉               유르
# 155         공예           스왈로우굿즈
# 186    디지털 드로잉              전구별
# 199         공예             별별그림
# 213    디지털 드로잉          뽐뽐 스튜디오
# 284  부업/창업/재테크               효샤
# 299    디지털 드로잉              흐스흐
# 364  부업/창업/재테크  미돌남 - 미싱 돌리는 남자
# 560    디지털 드로잉           클래스101
# 627     디자인/개발             포그보우
# 837         굿즈           클래스101

# %%
df[df['title'].str.contains('굿즈')].category.value_counts()
# Out:
# 디지털 드로잉      9
# 부업/창업/재테크    2
# 공예           2
# 디자인/개발       1
# 굿즈           1
# Name: category, dtype: int64

# %%
df_ddrawing[df_ddrawing['title'].str.contains('이모티콘')]
# Out:
#                                         title  favorite      price category  \
# 48                     민두 작가의 이모티콘 제작부터 판매까지!      5681  월 31,880원  디지털 드로잉
# 90               광팔의 아이패드로 귀염통통 카카O톡 이모티콘 만들기      4368  월 32,780원  디지털 드로잉
# 115                   식빵뚱냥과 귀염뽀짝 캐릭터 이모티콘 만들기      4080  월 38,900원  디지털 드로잉
# 246  모찌, 세숑, 바쁘개 이모티콘은 어떻게 만들었을까? 이모티콘 제작 입문!      2397  월 45,900원  디지털 드로잉
# 317            이모티콘 작가 오니기리와 함께 카카오톡 이모티콘 만들기      1946  월 34,900원  디지털 드로잉
# 371         귀여운 낙서로 돈 버는 법, 캐릭터로 이모티콘 연금 만들기!      1699  월 51,440원  디지털 드로잉
# 544                소소하지만 확실하게, 이모티콘으로 수익 창출하기       934  월 34,900원  디지털 드로잉
#
#       creator
# 48         화유
# 90         광팔
# 115      식빵뚱냥
# 246  이모티콘 좋아요
# 317      오니기리
# 371       김하나
# 544        수팡

# %%
df[df['title'].str.contains('굿즈')]
# Out:
#                                                title  favorite      price  \
# 17                  나만의 문방구를 차려요! 그리지영의 타블렛으로 굿즈 만들기      7770  월 30,400원
# 18                     취미를 넘어 굿즈 셀러로! 인쇄물 굿즈 제작과 상품화      7669  월 39,900원
# 41                         아이패드로 시작하는 캣빵의 귀여운 굿즈 만들기      6039  월 43,880원
# 71                     일러스트레이터 이공과 함께 나만의 미니 굿즈 제작하기      4907  월 35,900원
# 121                   소소하지만 확실한 행복, 유르의 굿즈 제작부터 판매까지      3905  월 36,900원
# 155                    실로 그리는 그림, 스왈로우굿즈의 일러스트 프랑스자수      3365  월 46,900원
# 186                       전구별과 떠나는 캐릭터 제작과 굿즈 만들기 세상      2996  월 43,046원
# 199                     별별그림의 실크스크린으로 쓱싹 만드는 유니크한 굿즈      2876  월 43,900원
# 213                          귀염뽀짝 일러스트 굿즈 만들기의 모든 것!      2794  월 43,880원
# 284                  내가 그린 캐릭터로 브랜드 시작하기! 굿즈부터 사업화까지      2169  월 49,676원
# 299  아이패드 드로잉의 기초부터 굿즈 제작까지, 따뜻하고 몽글몽글하게 흐스흐와 함께 해요!      2074  월 44,280원
# 364       내가 만든 수공예품, 그림 굿즈, 디지털 파일 판매로 엣시에서 돈 버는 법!      1726  월 45,632원
# 560                        [꿀조합 할인🍯] 귀염뽀짝한 굿즈 제작 입문편       880  월 29,908원
# 627                  잠들어 있던 사진첩 속 사진들로 나만의 굿즈를 만들어봐요       686  월 40,220원
# 837                약국의 센티멘탈 감성이 짙게 묻은 굿즈, 최대 40% 할인!       228    10,450원
#
#       category          creator
# 17     디지털 드로잉             그리지영
# 18     디지털 드로잉             사심굿즈
# 41     디지털 드로잉               캣빵
# 71     디지털 드로잉               이공
# 121    디지털 드로잉               유르
# 155         공예           스왈로우굿즈
# 186    디지털 드로잉              전구별
# 199         공예             별별그림
# 213    디지털 드로잉          뽐뽐 스튜디오
# 284  부업/창업/재테크               효샤
# 299    디지털 드로잉              흐스흐
# 364  부업/창업/재테크  미돌남 - 미싱 돌리는 남자
# 560    디지털 드로잉           클래스101
# 627     디자인/개발             포그보우
# 837         굿즈           클래스101

# %%
df[df['title'].str.contains('아이패드 드로잉')]
# Out:
#                                                title  favorite      price  \
# 3              일상에 따뜻한 숨결을 불어넣어요, 반지수와 함께하는 아이패드 드로잉     15509  월 44,900원
# 52                    현실과 환상사이, 그 어딘가를 그려내는 아이패드 드로잉      5422  월 47,880원
# 72            공간에 포근한 분위기를 불어넣어요, 반지수와 함께하는 아이패드 드로잉      4872  월 43,900원
# 117                          오유의 수채화 같은 아이패드 드로잉 클래스      4004  월 45,880원
# 124             사랑하는 작은 것들을 아기자기하게 그려요. 보담의 아이패드 드로잉      3853  월 45,880원
# 170                   감성 충전하는 아이패드 드로잉, 그림그리는방과 함께해요      3167  월 33,880원
# 195             너와 내가 그리는 가장 아름다운 순간들, 배성규의 아이패드 드로잉      2916  월 53,460원
# 254            소중했던 여행의 순간들을 기록해요, 김웃과 함께하는 아이패드 드로잉      2357  월 36,880원
# 272                      5가지 스타일을 한 번에! 달콩의 아이패드 드로잉      2241  월 37,880원
# 299  아이패드 드로잉의 기초부터 굿즈 제작까지, 따뜻하고 몽글몽글하게 흐스흐와 함께 해요!      2074  월 44,280원
# 314                  평범한 일상에 색을 더하는 시간, 자토의 아이패드 드로잉      1969  월 45,880원
# 402                  사물, 인물 그리고 풍경까지! 아이패드 드로잉의 모든 것      1541  월 38,880원
# 557             환상을 현실로 구체화하는 경험, 인디고의 두 번째 아이패드 드로잉       886  월 45,900원
# 568            꿈꾸는 일상 공간 속의 나, 리니와 기초부터 배우는 아이패드 드로잉       865  월 50,580원
# 612                  한 겹씩 쌓아가며 나만의 공간을 그려보는 아이패드 드로잉       740  월 46,440원
# 639                      내가 그리고, 네가 간직할 인공의 아이패드 드로잉       660  월 45,880원
# 656            행복했던 기억을 오랫동안 간직하고 싶다면, 신기루의 아이패드 드로잉       619  월 44,280원
# 749       삶의 디테일을 담은 아이패드 드로잉! 저와 함께 자신의 로망을 그려보실래요?       400  월 49,500원
# 780                                   아이패드 드로잉 악세사리        323    26,000원
# 799       말랑말랑한 선으로 기억하는 여행의 추억, ernho의 신나는 아이패드 드로잉       281  월 37,900원
#
#       category  creator
# 3      디지털 드로잉      반지수
# 52     디지털 드로잉      인디고
# 72     디지털 드로잉      반지수
# 117    디지털 드로잉       오유
# 124    디지털 드로잉       보담
# 170    디지털 드로잉   그림그리는방
# 195    디지털 드로잉      배성규
# 254    디지털 드로잉       김웃
# 272    디지털 드로잉       달콩
# 299    디지털 드로잉      흐스흐
# 314    디지털 드로잉       자토
# 402    디지털 드로잉  제이(Jay)
# 557    디지털 드로잉      인디고
# 568    디지털 드로잉       리니
# 612    디지털 드로잉       안쇰
# 639    디지털 드로잉       인공
# 656    디지털 드로잉      신기루
# 749    디지털 드로잉      성연성
# 780  디지털기기/ACC   클래스101
# 799    디지털 드로잉    ernho

# %%
df[df['category'] == '부업/창업/재테크']
# Out:
#                                                  title  favorite       price  \
# 0               스마트스토어로 월 100만원 만들기, 평범한 사람이 돈을 만드는 비법     18974   월 53,520원
# 10                        블로그로 하루 2시간 투자해서 직장인만큼 수익내기!      9226   월 45,632원
# 12                   나만의 취미로 돈 버는 방법, 디지털 파일 판매의 모든 것!      8807   월 39,750원
# 34                    15만 유튜버 자청의 자동수익 월 1,000만원 만드는 법      6443  월 111,298원
# 36                     월급으로 만족하지 못하는 분들을 위한 아마존/이베이 입문      6265   월 39,750원
# 73                       무자본, 무재고로 중국 구매 대행 사업/부업 시작하기      4797   월 43,058원
# 83                   월세 수익 300만 원을 만드는 송사무장의 부동산 투자법!       4474   월 27,740원
# 93              AI 자동 투자 봇 만들기, 노트북 하나로 월급을 두 배 불리는 비법      4327   월 66,446원
# 102                        자영업자를 위한 매출로 이어지는 인스타그램 마케팅      4231   월 36,442원
# 111                      평범한 사람이 돈 만드는 생각의 비밀, 머니 시크릿       4096   월 27,740원
# 116             무자본 마케팅의 시작, 네이버 블로그로 월 1,000만원 매출 올리기      4041   월 61,040원
# 152         20대, 30대를 위한 내 집 마련의 첫걸음, 부동산 공부는 빠를수록 좋다!      3416   월 50,778원
# 181             월 100만원 수익! 아이디어스, 스마트스토어에서 월급 외 수익 벌기      3035   월 43,058원
# 211                 뜬구름 잡지 않는 부동산 경매 투자법! 월급쟁이 부자는 없다.      2820   월 75,148원
# 284                    내가 그린 캐릭터로 브랜드 시작하기! 굿즈부터 사업화까지      2169   월 49,676원
# 315                         현직 뮤비 감독에게 배우는 감각적인 영상 제작법      1961   월 39,700원
# 328            하고싶은 일을 하며 살아보세요. 월급은 에어비앤비가 대신 벌어드립니다!      1896   월 41,278원
# 355                       열정을 돈으로 만드는 기술, 인스타그램 퍼스널브랜딩      1754   월 43,058원
# 364         내가 만든 수공예품, 그림 굿즈, 디지털 파일 판매로 엣시에서 돈 버는 법!      1726   월 45,632원
# 392                   집이 없어도 월세를 받을 수 있는 방법, 쉐어하우스 창업!      1587   월 43,058원
# 412           11만 유튜버 '대학생김머신'의 무엇이든 팔 수 있는 쇼핑몰 창업 가이드      1481   월 75,992원
# 442                      나만의 철학이 담긴 패션 브랜드 런칭하기 A to Z      1372   월 39,890원
# 449                  내 재능을 이용한 디지털 파일, 문서로 자동화 수입 만들기!      1335   월 47,690원
# 452           몰랑이 작가에게 배우는 잘 팔리는 캐릭터 디자인 & 캐릭터 매뉴얼 제작법      1330   월 51,348원
# 479                               주식투자, 운도 감도 아닌 학습입니다      1158   월 52,984원
# 499                       판타지 웹 소설 작가 되어 ‘내 글’로 돈 벌어보기      1088   월 49,676원
# 505             쿠팡 파트너스와 제휴 마케팅으로 집에서 월 200만 원 부수익 만들기      1069   월 43,058원
# 506      '브랜드'적으로 사업계획서 쓰는 비결! (+디자인씽킹 +브랜드컨셉 +마케팅 까지)      1067   월 42,986원
# 532                  사장님이여 회계하라! 자영업자가 생존하는 회계 시스템 만들기       969   월 34,374원
# 553         무자본, 무재고! 하루 30분 쿠팡 파트너스 등 제휴 마케팅으로 돈 버는 법       895   월 43,058원
# 561                          자동으로 돈을 버는 프로그램 만들기, 머니해킹       884   월 72,780원
# 567                 프리랜서로 N개의 직업을 가지며, 나만의 수익을 만드는 방법!       865   월 48,848원
# 575  내 스마트스토어 상품을 해외에 파는 법 : 쇼피파이로 매일 2시간 투자해서 수익 불리기!       838   월 52,984원
# 578                 한 시간에 210억 판 남자 장문정의 당장 돈 되는 상품 언어       839   월 58,498원
# 588                   무자본 인스타 마켓 창업, 좋아하는 일 하며 돈 버는 법!       799   월 50,778원
# 599         연봉 1억 유튜버가 도와주는 유튜버 되는 지름길, 채널 생성부터 수익화까지!       778   월 49,758원
# 603         스마트스토어보다 쉬운, 내 집 없이 쉐어하우스 투잡으로 월 200만원 만들기       764   월 41,044원
# 604             친절한 성 기자에게 배우는 재테크, 6개월 만에 천만 원 만드는 법!       756   월 52,984원
# 608                        무역공주 서이랑과 함께하는 알리바바로 40억 벌기       756   월 52,984원
# 617                     네일아트 기초부터 창업까지, 레나의 네일 인생 길라잡이       727   월 82,848원
# 621                 SM엔터테인먼트 전속 작곡가가 알려주는 프로 작곡가가 되는 법       695   월 63,322원
# 623                  마브사끼의 상품 하나로 스마트스토어 월 1,000만원 만들기       701   월 77,392원
# 648              온라인 스토어 사업화, 초보 티를 벗어나 연 매출 10억 이상으로!       630   월 49,676원
# 650                 여러분들의 재테크 목표 달성, 10년을 앞당겨 드리겠습니다.        629   월 69,800원
# 658              장사와 사업을 꿈꾸거나, 종사하는 사람에게 벌어지는 꼭 필요한 공식       609   월 52,984원
# 673                        나만의 의류 브랜드! 디자인부터 유통, 마케팅까지       587   월 46,366원
# 684                스타트업 투자로 재테크하라! 10배 수익 내는 비상장 주식 투자       556   월 45,632원
# 686                         처음 하는 주식 투자, 연 20% 수익 내는 법       550   월 52,984원
# 744                              네이버 블로그 체험단 수익 1억 만들기       407   월 49,520원
# 755              임대 소득을 만들어 확실하게 은퇴, 노후를 준비하는 부동산 재테크!       389  월 129,558원
# 758                     8조 규모의 <온라인 쇼핑몰>시장 에서 1등 되는 법!       378   월 47,520원
# 762                 망하지 않는 창업! 예비창업자를 위한 내 가게 준비의 모든 것       378   월 52,984원
# 790                 글로벌 주식 투자 - 앞서가는 부자가 되는, 가장 효율적 방법       313   월 56,280원
# 809      2030 직장인 내 집 마련을 위한 부동산 포트폴리오! 태유정의 하우스티칭 클래스       267   월 47,520원
# 816                             동네 장사로 살아남기 위한 특별한 전략!       255   월 45,632원
# 884              현민쌤의 부동산 경매! 알고 투자할 것인가? 모르고 투자할 것인가?       159   월 47,780원
# 891                      소프트뱅크벤처스 심사역에게 듣는다, 벤처캐피탈101!       154   월 65,524원
#
#       category          creator
# 0    부업/창업/재테크             신사임당
# 10   부업/창업/재테크           리뷰요정리남
# 12   부업/창업/재테크         노마드 그레이쓰
# 34   부업/창업/재테크        라이프 해커 자청
# 36   부업/창업/재테크              로꾸미
# 73   부업/창업/재테크           온라인탑셀러
# 83   부업/창업/재테크             송사무장
# 93   부업/창업/재테크            타임퍼센트
# 102  부업/창업/재테크         칙스토리 김종영
# 111  부업/창업/재테크             김새해
# 116  부업/창업/재테크           이상한김팀장
# 152  부업/창업/재테크              거상쌤
# 181  부업/창업/재테크              단아쌤
# 211  부업/창업/재테크        젊은부자마을 유비
# 284  부업/창업/재테크               효샤
# 315  부업/창업/재테크              이재웅
# 328  부업/창업/재테크             제제미미
# 355  부업/창업/재테크           드로우앤드류
# 364  부업/창업/재테크  미돌남 - 미싱 돌리는 남자
# 392  부업/창업/재테크             카인드쌤
# 412  부업/창업/재테크          대학생 김머신
# 442  부업/창업/재테크         이학림 디자이너
# 449  부업/창업/재테크        이은지(은짜언니)
# 452  부업/창업/재테크           몰랑이 작가
# 479  부업/창업/재테크          알머리 제이슨
# 499  부업/창업/재테크               진문
# 505  부업/창업/재테크      1프로마케터  서동민
# 506  부업/창업/재테크    興하게 도와드리는 흥소장
# 532  부업/창업/재테크              윤정용
# 553  부업/창업/재테크              단아쌤
# 561  부업/창업/재테크             머니해커
# 567  부업/창업/재테크           코스모지나
# 575  부업/창업/재테크              온도남
# 578  부업/창업/재테크              장문정
# 588  부업/창업/재테크              윤우맘
# 599  부업/창업/재테크             구스마일
# 603  부업/창업/재테크            쉐어마스터
# 604  부업/창업/재테크         친절한 성 기자
# 608  부업/창업/재테크             무역공주
# 617  부업/창업/재테크               레나
# 621  부업/창업/재테크   JM Studio Live
# 623  부업/창업/재테크             마브사끼
# 648  부업/창업/재테크             히든셀러
# 650  부업/창업/재테크           소사장소피아
# 658  부업/창업/재테크              정찬영
# 673  부업/창업/재테크             조니티비
# 684  부업/창업/재테크             대한팀장
# 686  부업/창업/재테크         절대수익 이재웅
# 744  부업/창업/재테크           다퍼주는남자
# 755  부업/창업/재테크              단희쌤
# 758  부업/창업/재테크             완판언니
# 762  부업/창업/재테크               창플
# 790  부업/창업/재테크           시그니처투자
# 809  부업/창업/재테크            하우스티칭
# 816  부업/창업/재테크           장사 권프로
# 884  부업/창업/재테크              현민쌤
# 891  부업/창업/재테크      벤처캐피탈리스트 제이
